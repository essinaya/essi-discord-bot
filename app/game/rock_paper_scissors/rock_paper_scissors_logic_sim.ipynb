# %%
#for time's sake, let's just assume the player won't enter any number besides 1,2,3. this is for testing the logic.
rps_dict = {1: "Rock", 2: "Paper", 3: "Scissors"}
game_state_dict = {1: "Win", 2: "Tie", 3: "Lose"}
results_dict = { 
    "Rock": 
        { 
            "Rock": 2,
            "Paper": 3,
            "Scissors": 1 
        },
    "Paper": 
        { 
            "Rock": 1,
            "Paper": 2,
            "Scissors": 3 
        },
    "Scissors": 
        { 
            "Rock": 3,
            "Paper": 1, 
            "Scissors": 2 
        } 
}

# %%
results_dict["Paper"]["Scissors"]
# Out:
# 3

# %%
players_choice = int(input("Choose: [1] Rock [2] Paper [3] Scissors: "))
# Out:
# Choose: [1] Rock [2] Paper [3] Scissors:  3

# %%
import random
def rock_paper_scissors(players_choice_int):
    #get the bot's choice by taking random number between 1-3
    bots_choice = random.randint(1,4)
    #get the player and bot's choice values by taking it in rps_dict
    players_choice_value = rps_dict[players_choice_int]
    bots_choice_value = rps_dict[bots_choice]
    print(f"Bot's choice: {bots_choice}")
    print(f"players_choice_value: {players_choice_value}")
    print(f"bots_choice_value: {bots_choice_value}")

    #check the result
    results = results_dict[players_choice_value][bots_choice_value]

    #bot now checks the result in game_state_dict
    game_state = game_state_dict[results]

    print(f"Player chooses {players_choice_value}!")
    print(f"Bot chooses {bots_choice_value}!")
    print(f"Player {game_state}s against Bot!")

# %%
rock_paper_scissors(players_choice)
# Out:
# Bot's choice: 1
# players_choice_value: Scissors
# bots_choice_value: Rock
# Player chooses Scissors!
# Bot chooses Rock!
# Player Loses against Bot!
